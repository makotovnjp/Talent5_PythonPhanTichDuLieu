# %% [markdown]
# # Đề bài
#
# Hãy lập trình cho hàm số rearrange

# %%
def rearrange(data):
    """
    data: list
    """
    # Start: Phần bạn code
    rearrange = []

    # End: Phần bạn code
    return rearrange

# %%
# Test
if rearrange([0, 1, 3, 4, 2, 4, 5, 1, 6, 9, 8]) == [0, 4, 2, 4, 6, 8, 1, 3, 5, 1, 9]:
    print('OK')
else:
    print('NG')
# Out:
# NG
